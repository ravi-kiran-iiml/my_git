# %% [markdown]
# <a href="https://colab.research.google.com/github/ravi-kiran-iiml/my_git/blob/master/Decision_Tree_Sklearn_datasets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn import tree
import graphviz

# %%
from sklearn.datasets import load_iris

data = load_iris()
X = data.data
y = data.target 

print(X.shape)
print(y.shape)

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)

model = tree.DecisionTreeClassifier()
model.fit(x_train, y_train)
predictions = model.predict(x_test)
print(model.score(x_test, y_test))

dot_data = tree.export_graphviz(model, out_file = None)
graph = graphviz.Source(dot_data)
graph
# Out:
# (150, 4)
# (150,)
# 0.9333333333333333

# %%
from sklearn.datasets import load_digits

data = load_iris()
X = data.data
y = data.target 

print(X.shape)
print(y.shape)

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)

model = tree.DecisionTreeClassifier()
model.fit(x_train, y_train)
predictions = model.predict(x_test)
print(model.score(x_test, y_test))

dot_data = tree.export_graphviz(model, out_file = None)
graph = graphviz.Source(dot_data)
graph
# Out:
# (150, 4)
# (150,)
# 0.9555555555555556

# %%
from sklearn.datasets import load_wine

data = load_iris()
X = data.data
y = data.target 

print(X.shape)
print(y.shape)

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)

model = tree.DecisionTreeClassifier()
model.fit(x_train, y_train)
predictions = model.predict(x_test)
print(model.score(x_test, y_test))

dot_data = tree.export_graphviz(model, out_file = None)
graph = graphviz.Source(dot_data)
graph
# Out:
# (150, 4)
# (150,)
# 0.9111111111111111

# %%
from sklearn.datasets import load_breast_cancer

data = load_iris()
X = data.data
y = data.target 

print(X.shape)
print(y.shape)

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)

model = tree.DecisionTreeClassifier()
model.fit(x_train, y_train)
predictions = model.predict(x_test)
print(model.score(x_test, y_test))

dot_data = tree.export_graphviz(model, out_file = None)
graph = graphviz.Source(dot_data)
graph
# Out:
# (150, 4)
# (150,)
# 0.9777777777777777

# %%
from sklearn.datasets import fetch_kddcup99

data = load_iris()
X = data.data
y = data.target 

print(X.shape)
print(y.shape)

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)

model = tree.DecisionTreeClassifier()
model.fit(x_train, y_train)
predictions = model.predict(x_test)
print(model.score(x_test, y_test))

dot_data = tree.export_graphviz(model, out_file = None)
graph = graphviz.Source(dot_data)
graph
# Out:
# (150, 4)
# (150,)
# 0.9333333333333333

# %%
from sklearn.datasets import fetch_rcv1

data = load_iris()
X = data.data
y = data.target 

print(X.shape)
print(y.shape)

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)

model = tree.DecisionTreeClassifier()
model.fit(x_train, y_train)
predictions = model.predict(x_test)
print(model.score(x_test, y_test))

dot_data = tree.export_graphviz(model, out_file = None)
graph = graphviz.Source(dot_data)
graph
# Out:
# (150, 4)
# (150,)
# 0.9555555555555556

# %%
from sklearn.datasets import fetch_20newsgroups_vectorized

data = load_iris()
X = data.data
y = data.target 

print(X.shape)
print(y.shape)

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)

model = tree.DecisionTreeClassifier()
model.fit(x_train, y_train)
predictions = model.predict(x_test)
print(model.score(x_test, y_test))

dot_data = tree.export_graphviz(model, out_file = None)
graph = graphviz.Source(dot_data)
graph
# Out:
# (150, 4)
# (150,)
# 0.9333333333333333
